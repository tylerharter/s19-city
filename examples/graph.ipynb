# %% [markdown]
# I installed this with the following:
#
# conda install python-graphviz

# %%
from graphviz import Digraph

# %%
g = Digraph()

g.node('Rock')
g.node('Paper')
g.node('Scissors')

g.edge('Rock', 'Scissors')
g.edge('Scissors', 'Paper')
g.edge('Paper', 'Rock')

g
